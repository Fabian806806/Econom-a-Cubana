# %% [markdown]
# # El Dilema del Ahorro en Cuba , USD vs CUP
#
# **Autor**: Fabian Enrique Morales
#
# **Fecha**: 15/10/25 - 19/12/25
#
# **contexto**: Proyecto de Ciencia de Datos , primer año / primer semestre
#
#
# En una economía con una marcada dualidad monetaria , el cubano de a pie enfrenta una gran variedad de problemáticas , entre ellas el poder economizar ingresos: "¿Cuándo y cómo?". Este proyecto busca analizar la viabilidad del peso cubano (CUP) como una moneda de ahorro , constrastándolo en algunos casos con el dólar estadounidense y analizando en primer lugar si tan siquiera es posible para un cubano promedio reservar una parte de sus ingresos.

# %%
import funciones as a 

print(a.maxmin("toque","Enero"))
# Out:
# 305 CUP , 341 CUP
